# %%
# !pip install cryptocompare
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Using legacy 'setup.py install' for cryptocompare, since package 'wheel' is not installed.
# ...
#     Running setup.py install for cryptocompare ... done
# ...

# %%
import cryptocompare
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.animation import FuncAnimation
from time import sleep

# %%
def getPrice(name):
    return cryptocompare.get_price(name,currency='USD')[name]['USD']

# %%
#to calculate percent difference
def getPriceDiff(name):
    inVal = getPrice(name)
    sleep(1)
    finVal = getPrice(name)
    diff = (finVal-inVal)/inVal
    return diff*100

# %%
print(getPriceDiff('ETH'))
# Out:
# 0.02058532092166921

# %%
plt.style.use('ggplot')
# %matplotlib notebook

# %%
timeVal = []
price = []
def animate(i):
  timeVal.append(datetime.now())
  price.append(getPriceDiff('ETH'))
  plt.title("Ethereum")
  plt.xlabel("Time")
  plt.ylabel("Price")
  plt.plot_date(timeVal,price,linestyle ="solid",ms=0)
  plt.tight_layout()

# %%
ani = FuncAnimation(plt.gcf(),animate,interval=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
