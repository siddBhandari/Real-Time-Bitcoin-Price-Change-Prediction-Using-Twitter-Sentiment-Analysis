# %%
# !pip install cryptocompare
# Out:
# Collecting cryptocompare
#   Downloading cryptocompare-0.7.5.tar.gz (5.2 kB)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from cryptocompare) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->cryptocompare) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->cryptocompare) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from requests->cryptocompare) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->cryptocompare) (1.26.4)
# Building wheels for collected packages: cryptocompare
#   Building wheel for cryptocompare (setup.py): started
#   Building wheel for cryptocompare (setup.py): finished with status 'done'
#   Created wheel for cryptocompare: filename=cryptocompare-0.7.5-py3-none-any.whl size=5066 sha256=6de26aa0ff25cb82f7e7b6eee3288d08b8e4136b9a18a70ee442c21f08ac9383
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\17\5b\b7\0b29e1ef74d0be7fc02e164e2a974a189e0423b4300c529815
# Successfully built cryptocompare
# Installing collected packages: cryptocompare
# Successfully installed cryptocompare-0.7.5

# %%
import cryptocompare
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.animation import FuncAnimation
from time import sleep

# %%
def getPrice(name):
    return cryptocompare.get_price(name,currency='USD')[name]['USD']

# %%
#to calculate percent difference
def getPriceDiff(name):
    inVal = getPrice(name)
    sleep(1)
    finVal = getPrice(name)
    diff = (finVal-inVal)/inVal
    return diff*100

# %%
print(getPriceDiff('ETH'))
# Out:
# 0.009565258979378167

# %%
plt.style.use('ggplot')
# %matplotlib notebook

# %%
timeVal = []
price = []
def animate(i):
  timeVal.append(datetime.now())
  price.append(getPriceDiff('ETH'))
  plt.title("Ethereum")
  plt.xlabel("Time")
  plt.ylabel("Price")
  plt.plot_date(timeVal,price,linestyle ="solid",ms=0)
  plt.tight_layout()

# %%
ani = FuncAnimation(plt.gcf(),animate,interval=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
