# %%
import requests
import os
import json

# %% [markdown]
# set bearer_token = < your bearer token > in the next line

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAH%2F2YgEAAAAA88cF6Vnz0h%2FofudQiZMYaC0kq%2BE%3DhXg1vaTm1vT95nTFmsMzAazWilrQ9KV3yHh8FXjWGekJSdF70F"

# %%
def bearer_oauth(r):
    # Method for authentication by bearer token
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r

# %%
def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

# %%
def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

# %%
def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "Bitcoin", "tag": "bitcoin AND btc"},
        {"value": "Ethereum", "tag": "ethereum AND eth"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

# %%
def get_stream(set):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
def main():
    rules = get_rules()
    delete = delete_all_rules(rules)
    set = set_rules(delete)
    get_stream(set)

# %%
if __name__ == "__main__":
    main()
# Out:
# {"data": [{"id": "1493683757601390592", "value": "cat has:images -grumpy", "tag": "cat pictures"}, {"id": "1493683757601390593", "value": "dog has:images", "tag": "dog pictures"}], "meta": {"sent": "2022-02-15T20:29:52.687Z", "result_count": 2}}
# {"meta": {"sent": "2022-02-15T20:29:53.321Z", "summary": {"deleted": 2, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1493684010156843009"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1493684010156843010"}], "meta": {"sent": "2022-02-15T20:29:54.032Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1493683986543034376",
#         "text": "RT @dog_rates: This is Aja. She was just told she's a good girl. Suspicions confirmed. 13/10 would tell again https://t.co/YfPliuwr4G"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683981572886531",
#         "text": "Dog of the Day \ud83d\udc36\n\nThis rare zombie Doggo is out there trying to find his soul mate. He knows in the Oasis Network they love $Rose \n\nPost your Doggo in the comments below \ud83d\udc47\ud83c\udffd\ud83d\udcaf\ud83c\udf39\n\n#NFT #OasisDogs #Rose #OasisNetwork #Oasis https://t.co/q2hVyGfpYJ"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683984617910278",
#         "text": "RT @pjmfilmz: the cat community and their love for their fellow kitty jimin https://t.co/fYamThD8pb"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683982919163913",
#         "text": "https://t.co/9FEsDOZApt"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683987465875463",
#         "text": "@BWorlder @Mecknavorz @dog_motif https://t.co/QmA4ej7Ar4"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683991374966788",
#         "text": "RT @pjmfilmz: the cat community and their love for their fellow kitty jimin https://t.co/fYamThD8pb"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683996680765442",
#         "text": "the natural light at the dog park was WORKING for d&amp;d this morning \ud83d\udc36\ud83d\udc9d https://t.co/PftNwvPTCy"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683997494370311",
#         "text": "RT @WestleySmith1: Dirty dog walk with my princess! \ud83d\udda4\ud83e\udd0d\ud83d\udc36 https://t.co/ZfVuBALriy"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493683998547140611",
#         "text": "Bwahahaha \nI live with the funniest cat! He was just chilling and sitting like that https://t.co/boU4HlmfaF"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684001789427717",
#         "text": "@NftCryptosArt Meet my black cat named Afonya\u2764\ufe0fhttps://t.co/F4T2i8KPJE\n#NFTCommunity https://t.co/QVLDaFbm0S"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684007019577345",
#         "text": "@backonceagain01 He's totally fine. https://t.co/rxvAOQMST2"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684007720013824",
#         "text": "RT @liIjiminvert: cat on cat appreciation https://t.co/zVtjlq6CXt"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684009536303104",
#         "text": "RT @dog_rates: This is Aja. She was just told she's a good girl. Suspicions confirmed. 13/10 would tell again https://t.co/YfPliuwr4G"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493

#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684049046474753",
#         "text": "RT @dvnsunshine: My dog is sick of my shit \ud83d\ude29\ud83d\ude02\ud83d\udc96 https://t.co/PFGjUf4F4j"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684043233300490",
#         "text": "America is OBSESSED with outlaw iconography. There really is no difference between Snoop Dog &amp; Merle Haggard if you really think about it except for RACIST bastards who want to blame Calvin for things they don't understand. https://t.co/MlGFEVDRhM"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684044655120386",
#         "text": "@WeebFae I swear on my cat's life https://t.co/rRMRzgfauc"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684049919025154",
#         "text": "RT @Punisher_Cat: \u041d\u0430\u0432\u0435\u0440\u043d\u043e\u0435 \u0432\u043f\u0435\u0440\u0432\u044b\u0435 \u044f \u0441\u043e\u0433\u043b\u0430\u0441\u0435\u043d \u0441 \u0421\u043e\u043b\u043e\u0432\u044c\u0435\u0432\u044b\u043c! \u0418 \u0436\u0435\u043b\u0430\u0442\u0435\u043b\u044c\u043d\u043e \u0441\u043f\u0440\u0430\u0432\u043e\u0447\u043a\u0443 \u0437\u0430\u0432\u0435\u0440\u0438\u0442\u044c \u043d\u043e\u0442\u0430\u0440\u0438\u0430\u043b\u044c\u043d\u043e!))) https://t.co/upQDDlJSB8"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843009",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1493684050443313158",
#         "text": "\ud83d\udc15  The recognizable FEMALE dog meme on the #BSC - REAL UTILITY \n\nMeme Swap coming this THURSDAY! + Meme university &amp; a meme coin social media network called \u00b4Coin Hub\u00b4 COMING SOON! \n\nDon\u2019t miss  @MrsCheems low market cap with HUGE POTENTIAL\ud83d\udd25\n\n#Sponsored https://t.co/onNe69TTu4"
#     },
#     "matching_rules": [
#         {
#             "id": "1493684010156843010",
#             "tag": "dog pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [25], in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Input In [19], in main()
#       3 delete = delete_all_rules(rules)
#       4 set = set_rules(delete)
# ----> 5 get_stream(set)
#
# Input In [18], in get_stream(set)
#       6 if response.status_code != 200:
#       7     raise Exception(
#       8         "Cannot get stream (HTTP {}): {}".format(
#       9             response.status_code, response.text
#      10         )
#      11     )
# ---> 12 for response_line in response.iter_lines():
#      13     if response_line:
#      14         json_response = json.loads(response_line)
#
# File /usr/lib/python3.10/site-packages/requests/models.py:802, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     793 """Iterates over the response data, one line at a time.  When
#     794 stream=True is set on the request, this avoids reading the
#     795 content at once into memory for large responses.
#     796
#     797 .. note:: This method is not reentrant safe.
#     798 """
#     800 pending = None
# --> 802 for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     804     if pending is not None:
#     805         chunk = pending + chunk
#
# File /usr/lib/python3.10/site-packages/requests/models.py:758, in Response.iter_content.<locals>.generate()
#     756 if hasattr(self.raw, 'stream'):
#     757     try:
# --> 758         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759             yield chunk
#     760     except ProtocolError as e:
#
# File /usr/lib/python3.10/site-packages/urllib3/response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     559 """
#     560 A generator wrapper for the read() method. A call will block until
#     561 ``amt`` bytes have been read from the connection or until the
#    (...)
#     572     'content-encoding' header.
#     573 """
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#     577 else:
#
# File /usr/lib/python3.10/site-packages/urllib3/response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     764     return
#     766 while True:
# --> 767     self._update_chunk_length()
#     768     if self.chunk_left == 0:
#     769         break
#
# File /usr/lib/python3.10/site-packages/urllib3/response.py:697, in HTTPResponse._update_chunk_length(self)
#     695 if self.chunk_left is not None:
#     696     return
# --> 697 line = self._fp.fp.readline()
#     698 line = line.split(b";", 1)[0]
#     699 try:
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
